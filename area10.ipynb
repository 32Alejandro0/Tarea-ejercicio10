# %%
pi=3.1416
r = float (input("Escriba el radio del circulo:"))
area = pi * r ** 2
print ("El area del circulo es:", area)
h = float (input( "Introduzca la altura del cilindro: "))
volumen = area * h
print ("El volumen del cilindro es:", volumen)
# Out:
# Escriba el radio del circulo:5
# El area del circulo es: 78.53999999999999
# Introduzca la altura del cilindro: 4
# El volumen del cilindro es: 314.15999999999997
